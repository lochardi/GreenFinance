# %%
from pathlib import Path
import xarray as xr

folder = Path("data_spei/")
files = sorted(folder.glob("*.nc"))

print(f"{len(files)} fichiers trouvés")

# Utiliser concat_dim='time' pour une meilleure combinaison sur la dimension temps
ds = xr.open_mfdataset(files, concat_dim='time', combine='nested')
print(ds)
print("\n" + "="*50)
print("Structure du dataset :")
print("="*50)
df = ds.to_dataframe().reset_index()
print(df.head(15))
# Out:
# 138 fichiers trouvés
# <xarray.Dataset> Size: 25MB
# Dimensions:  (time: 138, lat: 141, lon: 161)
# Coordinates:
#   * time     (time) datetime64[ns] 1kB 1980-05-01T06:00:00 ... 2025-07-01T06:...
#   * lat      (lat) float64 1kB 70.0 69.75 69.5 69.25 ... 35.75 35.5 35.25 35.0
#   * lon      (lon) float64 1kB -10.0 -9.75 -9.5 -9.25 ... 29.25 29.5 29.75 30.0
# Data variables:
#     SPEI3    (time, lat, lon) float64 25MB dask.array<chunksize=(1, 141, 161), meta=np.ndarray>
# Attributes: (12/17)
#     title:                   SPEI3
#     description:             Drought Index: Standardized Drought Index calcul...
#     Conventions:             CF-1.8
#     history:                 Created 18/08/2024 15:38:43 using DRYFALL.
#     institution:             European Centre for Medium-Range Weather Forecasts
#     source:                  DRYFALL v1.0
#     ...                      ...
#     climate_start_date:      1991-01-01
#     climate_end_date:        2020-12-31
# ...

# %%
print(df.head(15))
# Out:
#                   time   lat    lon  SPEI3
# 0  1980-05-01 06:00:00  70.0 -10.00    NaN
# 1  1980-05-01 06:00:00  70.0  -9.75    NaN
# 2  1980-05-01 06:00:00  70.0  -9.50    NaN
# 3  1980-05-01 06:00:00  70.0  -9.25    NaN
# 4  1980-05-01 06:00:00  70.0  -9.00    NaN
# 5  1980-05-01 06:00:00  70.0  -8.75    NaN
# 6  1980-05-01 06:00:00  70.0  -8.50    NaN
# 7  1980-05-01 06:00:00  70.0  -8.25    NaN
# 8  1980-05-01 06:00:00  70.0  -8.00    NaN
# 9  1980-05-01 06:00:00  70.0  -7.75    NaN
# 10 1980-05-01 06:00:00  70.0  -7.50    NaN
# 11 1980-05-01 06:00:00  70.0  -7.25    NaN
# 12 1980-05-01 06:00:00  70.0  -7.00    NaN
# 13 1980-05-01 06:00:00  70.0  -6.75    NaN
# 14 1980-05-01 06:00:00  70.0  -6.50    NaN

# %%
df_1 = df.dropna()
df_1.to_csv("data_spei/data1.csv", index=False)

# %%
#df_2 = df_1[(df_1['lat'] == 40.56338) & (df_1['lon'] == -2.5)]
df_2 = df_1[(df_1['lat'] == 40.5) & (df_1['lon'] == -3.75)]
df_2.to_csv("data_spei/data2.csv", index=False)
print(df_2.head(15))
# Out:
#                       time   lat   lon     SPEI3
# 19023  1980-05-01 06:00:00  40.5 -3.75  0.735186
# 41724  1980-06-01 06:00:00  40.5 -3.75  0.985201
# 64425  1980-07-01 06:00:00  40.5 -3.75  1.174805
# 87126  1981-05-01 06:00:00  40.5 -3.75  0.886932
# 109827 1981-06-01 06:00:00  40.5 -3.75  1.039537
# 132528 1981-07-01 06:00:00  40.5 -3.75  0.414217
# 155229 1982-05-01 06:00:00  40.5 -3.75  0.001371
# 177930 1982-06-01 06:00:00  40.5 -3.75  0.335761
# 200631 1982-07-01 06:00:00  40.5 -3.75  0.748095
# 223332 1983-05-01 06:00:00  40.5 -3.75 -0.077938
# 246033 1983-06-01 06:00:00  40.5 -3.75  0.400556
# 268734 1983-07-01 06:00:00  40.5 -3.75  0.254735
# 291435 1984-05-01 06:00:00  40.5 -3.75  1.314107
# 314136 1984-06-01 06:00:00  40.5 -3.75  1.495179
# 336837 1984-07-01 06:00:00  40.5 -3.75  1.501731

# %%
# moyenne par jour (en groupant sur la colonne time)
df_3 = df_2.groupby('time').mean().reset_index()
df_3.to_csv("data_spei/data3.csv", index=False)
print(df_3.head(15))
# Out:
#                   time   lat   lon     SPEI3
# 0  1980-05-01 06:00:00  40.5 -3.75  0.735186
# 1  1980-06-01 06:00:00  40.5 -3.75  0.985201
# 2  1980-07-01 06:00:00  40.5 -3.75  1.174805
# 3  1981-05-01 06:00:00  40.5 -3.75  0.886932
# 4  1981-06-01 06:00:00  40.5 -3.75  1.039537
# 5  1981-07-01 06:00:00  40.5 -3.75  0.414217
# 6  1982-05-01 06:00:00  40.5 -3.75  0.001371
# 7  1982-06-01 06:00:00  40.5 -3.75  0.335761
# 8  1982-07-01 06:00:00  40.5 -3.75  0.748095
# 9  1983-05-01 06:00:00  40.5 -3.75 -0.077938
# 10 1983-06-01 06:00:00  40.5 -3.75  0.400556
# 11 1983-07-01 06:00:00  40.5 -3.75  0.254735
# 12 1984-05-01 06:00:00  40.5 -3.75  1.314107
# 13 1984-06-01 06:00:00  40.5 -3.75  1.495179
# 14 1984-07-01 06:00:00  40.5 -3.75  1.501731
